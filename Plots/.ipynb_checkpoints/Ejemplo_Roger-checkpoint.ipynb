# %%
import Predictability_Entropy_TEST as pe
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1066: UserWarning: Duplicate key in file "/usr/local/lib/python2.7/dist-packages/matplotlib/mpl-data/matplotlibrc", line #619
#   (fname, cnt))

# %% [markdown]
# ## This is a title
#
# Here, we investigate whether blah-blah using
# $$
# f(x) = \frac{\sin x}{x}
# $$

# %%
pe.run(['S-8_Tot'])
pe.run(['V-10_Tot'])
pe.run(['V-22_Tot'])
pe.run(['V-23_24_Tot'])
pe.run(['V-25_Tot'])
# Out:
# {-6196.27: 7, -6319.82: 9, -6288.79: 3, -6268.58: 1, -6290.01: 5}
# -6196.27
# 7
# [[69. 15.]
#  [11. 33.]]
# {0: 0.8625, 1: 0.6875}
# {0: 0.8214285714285714, 1: 0.75}
# 0.4852941176470588
# 0.5862068965517241
# 0.0
# 0.0
# Predictability_Entropy_TEST.py:405: RuntimeWarning: invalid value encountered in double_scalars
#   (sum(Actual))#+NanSaver)
# {-6400.06: 1, -6442.19: 3, -6422.88: 5, -6431.04: 9, -6513.22: 7}
# -6400.06
# 1
# [[41. 16.]
#  [ 5. 75.]]
# {0: 0.8913043478260869, 1: 0.8241758241758241}
# {0: 0.7192982456140351, 1: 0.9375}
# 0.4722222222222222
# 0.6304347826086957
# 0.0
# 0.0
# Predictability_Entropy_TEST.py:401: RuntimeWarning: invalid value encountered in double_scalars
#   (sum(Predicted))#+NanSaver)
# {-31771.9: 1, -31849.6: 7, -31816.3: 9, -31825.4: 5, -31814.1: 3}
# -31771.9
# 1
# [[69.  8.]
#  [11. 46.]]
# {0: 0.8625, 1: 0.8518518518518519}
# {0: 0.8961038961038961, 1: 0.8070175438596491}
# 0.43478260869565216
# 0.4772727272727273
# 0.0
# 0.0
# ...
